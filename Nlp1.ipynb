# %%
import requests
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ali\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def extract(url):
    response = requests.get(url)
    html_content = response.text
    # Remove HTML tags using regular expressions
    text = re.sub(r'<[^>]*>', '', html_content)
    return text

# %%
def process_text(text):
    # Cleaning data
    text = ''.join(e for e in text if e.isalnum() or e.isspace())
    # Normalization
    text = text.lower()
    # Tokenization
    words = nltk.word_tokenize(text)
    # Lemmatization or Stemming
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    # Stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    return words

# %%
def unique(words):
    return set(words)

# %%
url = 'https://en.wikipedia.org/wiki/Mohamed_Salah'
text = extract(url)
words = process_text(text)
unique_words = unique(words)
print(unique_words)
# Out:
# {'provided', 'colombia', 'three', 'lampard', 'leverkusen918893', 'fight', 'sideboxabovebelowmwparseroutput', 'italy', 'overall', 'radio', 'comeback', 'earns', 'drought', 'charles', '100th', '9136793', 'aaron', 'fourfourtwo', '302', 'land', 'yeboah', 'age912293', 'leverkusen', 'download', 'pfc', 'announced', 'throughout', 'seasons9120293', 'strip', 'لسنة', 'sevenyearold', '200708', 'maker', '9137593', 'coutinho', 'francesco', 'ended', 'child', 'poor', 'create', 'tournament9125593', '2016179134193', 'became', '9136493', 'garoua', 'trolled', 'fut', '09emtextaligncentermwparseroutput', '1', 'bsc', 'frei', 'johnston', 'description', 'bruised', 'regexp', 'lift', 'huge', 'goals9150293', 'national', 'arabs911693911793', '160ghana', 'title9117493', 'sign', 'de', 'approximately', 'damaged', 'elite', 'fouryear', 'time912793', '15120172018', 'explosiveness', '9138693', 'لاعب', 'playerschelsea', '2960', 'lineup', 'yousef', 'rob', 'champion', 'afcon2021', 'current', 'education916093', 'kenny', '20229143193', '38game', 'mcgrath', 'sends', '201415', 'size', 'katongo', 'interested', '21', '47', 'original', '17160elneny', 'johnson', 'ligament', 'shirt', '21youth', 'defender', '200001', 'found', '77', 'draw913893', 'adel', 'flair', 'burn', 'articlesengvarb', 'fiorentinas', '15520212022', 'dominate', 'source', 'thomas', 'praise', '20239141893', 'broken', 'carroll', 'city', 'cs1locksubscription', 'squire', 'gabon', 'belgrade', 'deliberately', 'lynch', 'alex', 'barnetta', 'sent', '20239143293', '14em', 'brady', 'footballersmens', 'odums', 'shootouts91268939126993', 'talksport', 'shenawy', 'decision91146939114793', 'fathi', 'registration', 'injured', 'jr', 'dor', 'almonitor', '25160zizo', 'abdel', '198687', 'aggregate9110393', 'job9131093', 'redirects', 'several', 'august9124093', 'integral', '20219142193', '1958', 'career', 'merseyside', 'assisting', 'weah', 'stoppage', 'married', 'equal', '160guineabissau', 'dijk160c', 'cancelo', 'earlier9111893', 'ball', 'lyon', 'enciso', 'outside', 'abackgroundurluploadwikimediaorgwikipediacommons44cwikisourcelogosvgright', 'henson', 'jorge', '20112020', 'lucas', 'bodyskinminerva', 'lot', 'extraordinary', 'lyric', 'estádio', '2023249139993', 'alli', '40', 'april', 'posting', 'basler', 'spotted', 'fixture', 'confronting', 'attacking', 'navboxsubgroupwidth100mwparseroutput', 'round914693', 'editcommunity', 'possibly', 'milner', 'illustrated', '20149118893', 'equality', 'vectorfeaturelimitedwidthclientpref1', 'single', '9160sherif', 'vteafrican', 'leicester', 'reflistloweralphaliststyletypeloweralphamwparseroutput', '9160hassan', 'reflist', 'closing', 'cleaner', 'informationcurrent', '2022239134993', 'divisionpremier', 'coulibaly', 'atalanta', '2017189147993', 'inside', 'vectorfeaturestickyheaderdisabled', 'raynor', 'embolo', 'saudi', 'fsf', 'league', 'scholar', 'giulia', 'counterlistitema0', 'rawson', 'erode', 'lineheight0mwparseroutput', 'doha', '2021229139793', 'crazyfast', 'reported', 'everywhere9129893', 'الجزء', 'financially', 'occasion', 'taking', 'proud', 'navboxnavboxmwparseroutput', 'prefreplaceclientprefwwgclientprefw', '26', 'abdelfattah', 'leftalignedtextalignleftmwparseroutput', 'rashford', '100', 'newcastle', 'receive', 'captiondisplaytablecaption', '1965', 'rlqwindowrlqpushfunctionmwloaderimplfunctionreturnuseroptions12s5ifunctionjqueryrequiremodulemwusertokenssetpatroltokenwatchtokencsrftoken', '160botswana', '2021229144093', 'delighted', 'century', 'bassogog', '17160el', 'drogba', 'ahmadu', 'de160bruyne', 'planning', 'hakimi', 'traoré', 'deal', 'mikel', 'arabiclanguage', 'xavi', 'muslimshidden', 'him9132893', 'half', 'praising', '11youth', 'morning', 'cited', 'economist', 'spanishlanguage', '2160b', 'stage914893', 'cristiano', '2024use', 'west', '202122', 'wing', 'ballon', 'bremner', 'trio', '9137293', 'thriller', 'erling', 'muslim9115393', 'inspires', 'bin', 'لقاء', 'bench', 'thirdbest', 'nagrig', '200506', 'finished', 'spanned', 'siro', 'urldownload', 'crisis9131293', '699115993', 'occupy', 'zen ...
